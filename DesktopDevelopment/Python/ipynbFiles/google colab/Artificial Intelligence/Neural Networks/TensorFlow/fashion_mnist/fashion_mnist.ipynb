# %% [markdown]
# #import

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #train dataset

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

class_names = ["Camiseta", "Calca", "Sueter", "Vestido", "Casaco", "Sandalia", "Camisa", "Tenis", "Bolsa", "Bota"]

x = 0
class_names[train_labels[x]]

train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# #neural network

# %%
#structure
model = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28, 28)), #input
                          keras.layers.Dense(128, activation = tf.keras.layers.LeakyReLU(alpha=0.1)), #hidden
                          keras.layers.Dense(10, activation='softmax') #output
])

# %%
#train
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics="accuracy")
model.fit(train_images, train_labels, epochs = 10)
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose = 2) 
print(f"acc: {test_acc}")
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.5027 - accuracy: 0.8240
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3825 - accuracy: 0.8614
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3439 - accuracy: 0.8744
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3181 - accuracy: 0.8835
# Epoch 5/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3008 - accuracy: 0.8895
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2876 - accuracy: 0.8934
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2752 - accuracy: 0.8991
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2666 - accuracy: 0.9000
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2560 - accuracy: 0.9046
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2489 - accuracy: 0.9076
# 313/313 - 1s - loss: 0.3326 - accuracy: 0.8836 - 587ms/epoch - 2ms/step
# acc: 0.8835999965667725

# %% [markdown]
# #run

# %%
plt.figure()
plt.imshow(train_images[x])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
plt.figure(figsize = (10, 10))
for i in range(25):
  plt.subplot(5, 5, i+1)
  plt.xticks([])
  plt.yticks([])

  plt.grid(False)
  plt.imshow(train_images[i], cmap = plt.cm.binary)
  plt.xlabel(class_names[train_labels[i]])
  plt.show()
